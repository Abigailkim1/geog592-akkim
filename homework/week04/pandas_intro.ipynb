# %% [markdown]
# <div style="
#     background-color: #7BAFD4;
#     border-radius: 18px;
#     padding: 22px 26px;
#     display: flex;
#     align-items: center;
#     gap: 24px;
#     margin-bottom: 18px;
# ">
#     <img src="../592_avatar_lr.png" alt="GEOG 592"
#         style="width:110px;height:110px;border-radius:22px;">
#     <div>
#         <div style="
#             font-family: Impact, 'Arial Black', Arial, sans-serif;
#             font-size: 42px;
#             font-weight: 900;
#             letter-spacing: 2px;
#             line-height: 1;
#             color: white;
#         ">GEOG 592</div>
#         <div style="
#             font-family: Arial, Helvetica, sans-serif;
#             font-size: 22px;
#             font-weight: 700;
#             color: #13294B;
#             margin-top: 8px;
#         ">GIS Programming</div>
#         <div style="
#             font-family: Arial, Helvetica, sans-serif;
#             font-size: 16px;
#             color: #13294B;
#             margin-top: 6px;
#         ">Week 4 Homework: Pandas Intro</div>
#     </div>
# </div>

# %% [markdown]
# ## Instructions:
#
# Using the cleaned CSV file from the previous homework, create a Jupyter Notebook that opens and explores the data using pandas.
#
# Use the following methods:
#
# df.head()
#
# df.shape
#
# df.columns
#
# df.dtypes
#
# df.info()
#
# Also use a mask to create a dataframe with less rows.

# %% [markdown]
# ## Dataframe exploration

# %%
import pandas as pd 
print(pd.__version__)
# Out:
# 3.0.3

# %%
df = pd.read_csv("data/bmf_filtered.csv")
df.head()
# Out:
#           ein                 org_name_display  \
# 0  01-0477310       Christian Mission Services
# 1  01-0616952           Christ Our Hope Church
# 2  01-0636457               Grace Ministries I
# 3  01-0649099  Apex Highschool A O I T Support
# 4  01-0667136            Reunite Cultures Fund
#
#                                 org_addr_full         ntee_code_major_group  \
# 0    200 COMMONWEALTH CT, CARY, NC 27511-2431                     UNDEFINED
# 1  203 CAPCOM AVE, WAKE FOREST, NC 27587-6514                     UNDEFINED
# 2      6717 VERNIE DR, RALEIGH, NC 27603-8549           Housing and Shelter
# 3   1501 LAURA DUNCAN RD, APEX, NC 27502-1539                     Education
# 4    7920 LAGENARIA DR, ANGIER, NC 27501-5503  Arts, Culture and Humanities
#
#    ntee_code_definition                                     geo_match_addr  \
# 0             UNDEFINED   200 Commonwealth Ct, Cary, North Carolina, 27511
# ...

# %%
# This is an attribute of the dataframe object. Methods have ().
print(df.shape)
# Out:
# (6310, 9)

# %%
df.columns
# Out:
# Index(['ein', 'org_name_display', 'org_addr_full', 'ntee_code_major_group',
#        'ntee_code_definition', 'geo_match_addr', 'geo_county', 'geo_lat',
#        'geo_lon'],
#       dtype='str')

# %%
df.dtypes
# Out:
# ein                          str
# org_name_display             str
# org_addr_full                str
# ntee_code_major_group        str
# ntee_code_definition         str
# geo_match_addr               str
# geo_county                   str
# geo_lat                  float64
# geo_lon                  float64
# dtype: object

# %%
# Prints the first and last rows 
df.info
# Out:
# <bound method DataFrame.info of              ein                      org_name_display  \
# 0     01-0477310            Christian Mission Services
# 1     01-0616952                Christ Our Hope Church
# 2     01-0636457                    Grace Ministries I
# 3     01-0649099       Apex Highschool A O I T Support
# 4     01-0667136                 Reunite Cultures Fund
# ...          ...                                   ...
# 6305  99-5045201  North Carolina Cantonese Association
# 6306  99-5058846                          Dah Ministry
# 6307  99-5076527                   Reading With George
# 6308  99-5108063                            Hockey Joy
# 6309  99-5139323        Our Journey Camping Experience
#
#                                      org_addr_full  \
# 0         200 COMMONWEALTH CT, CARY, NC 27511-2431
# 1       203 CAPCOM AVE, WAKE FOREST, NC 27587-6514
# 2           6717 VERNIE DR, RALEIGH, NC 27603-8549
# 3        1501 LAURA DUNCAN RD, APEX, NC 27502-1539
# ...

# %% [markdown]
# ## Creating a mask

# %%
mask = df['ntee_code_major_group'] == 'Housing and Shelter'
mask.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: ntee_code_major_group, dtype: bool

# %%
if len(df) == len(mask):
    print(f"df and mask are the same length ({len(df)} rows).")
else: 
    print("Not the same length.")
# Out:
# df and mask are the same length (6310 rows).

# %%
df_housing = df[mask]
df_housing.head()
# Out:
#             ein                                 org_name_display  \
# 2    01-0636457                               Grace Ministries I
# 90   13-4312776                        Alabama Nonprofit Housing
# 114  16-1640109  Communtiy Apartments Corporation Of Metrolina 5
# 151  20-0953592                   Blessed Life Housing Authority
# 325  20-8715100                    Captrust Community Foundation
#
#                                          org_addr_full ntee_code_major_group  \
# 2               6717 VERNIE DR, RALEIGH, NC 27603-8549   Housing and Shelter
# 90   8801 FAST PARK DR STE 117, RALEIGH, NC 27617-4853   Housing and Shelter
# 114  353 E SIX FRKS RD STE 300, RALEIGH, NC 27609-7887   Housing and Shelter
# 151          6220 BIG SANDY DR, RALEIGH, NC 27616-5797   Housing and Shelter
# 325  4208 SIX FRKS RD STE 1700, RALEIGH, NC 27609-5734   Housing and Shelter
#
#                        ntee_code_definition  \
# 2                         Homeless Shelters
# ...

# %%
df_housing_alt = df[df['ntee_code_major_group'] == 'Housing and Shelter']

df_housing_alt.head()
# Out:
#             ein                                 org_name_display  \
# 2    01-0636457                               Grace Ministries I
# 90   13-4312776                        Alabama Nonprofit Housing
# 114  16-1640109  Communtiy Apartments Corporation Of Metrolina 5
# 151  20-0953592                   Blessed Life Housing Authority
# 325  20-8715100                    Captrust Community Foundation
#
#                                          org_addr_full ntee_code_major_group  \
# 2               6717 VERNIE DR, RALEIGH, NC 27603-8549   Housing and Shelter
# 90   8801 FAST PARK DR STE 117, RALEIGH, NC 27617-4853   Housing and Shelter
# 114  353 E SIX FRKS RD STE 300, RALEIGH, NC 27609-7887   Housing and Shelter
# 151          6220 BIG SANDY DR, RALEIGH, NC 27616-5797   Housing and Shelter
# 325  4208 SIX FRKS RD STE 1700, RALEIGH, NC 27609-5734   Housing and Shelter
#
#                        ntee_code_definition  \
# 2                         Homeless Shelters
# ...
