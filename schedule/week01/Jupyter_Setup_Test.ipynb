# %% [markdown]
# <div align="center">
#
# # GEOG 592: Python + Jupyter Setup Test
#
# ### You are almost there.
#
# This short test will confirm that **Python, Jupyter, and VS Code are working correctly on your computer**.
#
# ---
#
# ## Step 1 — Change Your Name
#
# In the Python cell below, find this line:
#
# ```python
# name = "Student Name"
# ```
#
# Replace **`Student Name`** with **your name**.
#
# For example:
#
# ```python
# name = "Your Name"
# ```
#
# Keep the quotation marks.
#
# ---
#
# ## Step 2 — Run the Cell
#
# Click the **▶ Run button** to the left of the Python cell.
#
# ### Running a notebook for the first time?
#
# VS Code may ask you to select a **Python Environment** or **Kernel**.
#
# Select the **most recent version of Python that you installed**.
#
# For example, you may see something like:
#
# `Python 3.13`
#
# You do **not** need to create a new environment for this exercise.
#
# ---
#
# ## Step 3 — Check the Result
#
# If the cell runs and you receive a congratulations message:
#
# ### Your setup is working.
#
# `Python` · `Jupyter` · `VS Code` · `GIS Programming`
#
# ---
#
# </div>

# %%
name = "Javier"

print()
print("=" * 50)
print(f"CONGRATULATIONS, {name.upper()}!")
print("=" * 50)
print()
print("Python .......... WORKING")
print("Jupyter ......... WORKING")
print("VS Code ......... WORKING")
print()
print("Your GEOG 592 professor is officially happier.")
print("=" * 50)
# Out:
# ...
# CONGRATULATIONS, JAVIER!
# ...
#
# Python .......... WORKING
# Jupyter ......... WORKING
# VS Code ......... WORKING
#
# Your GEOG 592 professor is officially happier.
# ...
